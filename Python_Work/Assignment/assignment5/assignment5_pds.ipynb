# %%
def f1(a : int,b : float) -> float:
    """
    This functon accepts two parameters first is int type and second is float type and returns a float type
    """
    return a+b

def f2(a: int,b : int, c : str = '-') -> str:
    """
    This functon accepts three parameters first two are int type and third is string type with a default value
    '-' 
    It returns a string type
    """
    return str(a) + c + str(b)

#print(f1(1))
print(f'{"-"*10}1{"-"*10}')
print(f1(1,2))
print(f'{"-"*10}2{"-"*10}')
print(f1(1,2.3))
print(f'{"-"*10}3{"-"*10}')
print(f1(a=1,b=2))
print(f'{"-"*10}4{"-"*10}')
print(f1(a=1,b=2.3))
print(f'{"-"*10}5{"-"*10}')
#print(f1(1,2,3))
print(f'{"-"*10}6{"-"*10}')
#print(f1(1,a=1))
print(f'{"-"*10}7{"-"*10}')
#print(f1(1,c=2))
print(f'{"-"*10}8{"-"*10}')
print(f1(1,b=2))
print(f'{"-"*10}9{"-"*10}')
print(f1(1,b=2.3))
print(f'{"-"*10}10{"-"*10}')
print(f1(1.1,2.3))

def deco_func1(f):
    """
    This function decorates the function f1 for parameter validation
    """
    def inner_func(*args,**kwargs):
        # your program goes below ---->>>>>
        # develop this function such the when the commented lines are uncommented one by one they
        # display the corresponding error as indicated in the respective comments
        # you will need to work by manually raising Exceptions with the corressponding messages
        # delete the pass statement below and write your own program here
        
        if len(args)+len(kwargs)>=2:
            if len(args)==1 and len(kwargs)==1:
                if type(args[0])==int and type(kwargs['b'])==float:
                    return f(args[0],kwargs['b'])
                if 'b' not in kwargs.keys():
                    raise Exception("Exception: function : f1 has not been supplied the correct keyword parameter")
                if type(kwargs['b']) is not float:
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
            if len(args)==0:
                if type(kwargs['a'])== int and type(kwargs['b']) ==float:
                    return f(**kwargs)
                else : 
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
            if len(kwargs)==0:
                if len(args)>=2:
                    if type(args[0])==int and type(args[1])==float:
                        return f(args[0],args[1])
                    else:
                        raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
                else:
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
        else :
            raise Exception("Exception: function : f1 has not been supplied the correct number of parameters")
        return f(*args,**kwargs) 
    return inner_func

f1 = deco_func1(f1)

# print(f1(1)) # if uncommented gives message "Exception: function : f1 has not been supplied the correct number of parameters"
print(f'{"-"*10}1{"-"*10}')
# print(f1(1,2))  # if uncommented gives message "Exception: function : f1 has not been supplied parameters of proper type"
print(f'{"-"*10}2{"-"*10}')
print(f1(1,2.3))
print(f'{"-"*10}3{"-"*10}')
# print(f1(a=1,b=2))  # if uncommented gives message "Exception: function : f1 has not been supplied parameters of proper type"
print(f'{"-"*10}4{"-"*10}')
print(f1(a=1,b=2.3))
print(f'{"-"*10}5{"-"*10}')
# print(f1(1,2,3))  # if uncommented gives message "Exception: function : f1 has not been supplied parameters of proper type"
print(f'{"-"*10}6{"-"*10}')
# print(f1(1,a=1))  # if uncommented gives message "Exception: function : f1 has not been supplied the correct keyword parameter"
print(f'{"-"*10}7{"-"*10}')
# print(f1(1,c=2))  # if uncommented gives message "Exception: function : f1 has not been supplied the correct keyword parameter"
print(f'{"-"*10}8{"-"*10}')
# print(f1(1,b=2))  # if uncommented gives message "Exception: function : f1 has not been supplied parameters of proper type"
print(f'{"-"*10}9{"-"*10}')
print(f1(1,b=2.3)) 
print(f'{"-"*10}10{"-"*10}')
# print(f1(1.1,2.3))  # if uncommented gives message "Exception: function : f1 has not been supplied parameters of proper type"
print(f'{"-"*10}11{"-"*10}')
print(f1(b=2.3,a=1))
print(f'{"-"*10}12{"-"*10}')
print(f1(1,2.3,3,4))
# Out:
# ----------1----------
# 3
# ----------2----------
# 3.3
# ----------3----------
# 3
# ----------4----------
# 3.3
# ----------5----------
# ----------6----------
# ----------7----------
# ----------8----------
# 3
# ----------9----------
# 3.3
# ----------10----------
# 3.4
# ----------1----------
# ----------2----------
# 3.3
# ----------3----------
# ----------4----------
# 3.3
# ----------5----------
# ----------6----------
# ----------7----------
# ----------8----------
# ----------9----------
# 3.3
# ----------10----------
# ----------11----------
# 3.3
# ----------12----------
# 3.3

# %%
f2(1,"2",'+')
# Out:
# '1+2'

# %%
  
def deco_func2(f):
    def inner_func(*args,**kwargs):
        # if len(args)+len(kwargs)==2:
        #     if len(args)==0:
        #         if 'a' and 'b' in kwargs.keys():
        #             return f(kwargs['a'],kwargs['b'])
        #         else:
        #             raise Exception("")
        #     if len(kwargs)==0:
        #         if type(args[0]) and type(args[1]) == int:
        #             return f(args[0],args[1])
        #         else:
        #             raise Exception("")
        #     if len(args)==1 and len(kwargs)==1:
        #         if type(args[0]) and type(kwargs['b'])==int:
        #             return f(args[0],kwargs['b'])
        #         else:
        #             raise Exception("")

        # # print(args,kwargs)
        # # print(type(kwargs['a']))
        # if len(args)+len(kwargs)==3:
        #     if len(args)==0:
        #         if type(kwargs['a'])==int and type(kwargs['b']) ==int and type(kwargs['c'])==str:
        #             return f(**kwargs) 
        #         else:
        #             raise Exception("")
        #     if len(kwargs)==0:
        #         if type(args[0])==int and type(args[1]) ==int and type(args[2])==str:
        #             print(args)
        #             return f(*args)
        #         else :
        #             raise Exception("")
        #     if len(args)==1 and len(kwargs)==2:    
        #         pass
        # return f(*args,**kwargs)
        print(len(args),len(kwargs))
        if len(args)+len(kwargs)>=2:
            if len(args)==1 and len(kwargs)==1:
                print(type(args[0]))
                if type(args[0])==int and type(kwargs['b'])==int:
                    return f(args[0],kwargs['b'])
                if 'b' not in kwargs.keys():
                    raise Exception("Exception: function : f1 has not been supplied the correct keyword parameter")
                if type(kwargs['b']) is not int:
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
            if len(args)==0:
                if type(kwargs['a'])== int and type(kwargs['b']) ==int:
                    return f(**kwargs)
                else : 
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
            if len(kwargs)==0:
                if len(args)>=2:
                    if type(args[0])==int and type(args[1])==int:
                        return f(args[0],args[1])
                    else:
                        raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
                else:
                    raise Exception("Exception: function : f1 has not been supplied parameters of proper type")
        else :
            raise Exception("Exception: function : f1 has not been supplied the correct number of parameters")
        return f(*args,**kwargs)
    return inner_func 
f2=deco_func2(f2)

# #print(f2(1))
# print(f'{"-"*10}1{"-"*10}')
# print(f2(1,2))
# print(f'{"-"*10}2{"-"*10}')
# # print(f2(1,2.3))
# print(f'{"-"*10}3{"-"*10}')
# print(f2(a=1,b=2))
# print(f'{"-"*10}4{"-"*10}')
# print(f2(a=1,b=2.3))
# print(f'{"-"*10}5{"-"*10}')
# # print(f2(1,2,3))
# print(f'{"-"*10}6{"-"*10}')
# #print(f2(1,a=1))
# print(f'{"-"*10}7{"-"*10}')
# #print(f2(1,c=2))
# print(f'{"-"*10}8{"-"*10}')
# print(f2(1,b=2))
# print(f'{"-"*10}9{"-"*10}')
# print(f2(1,b=2.3))
# print(f'{"-"*10}10{"-"*10}')
# print(f2(1.1,2.3))
# print(f'{"-"*10}11{"-"*10}')
# print(f2(b=2.3,a=1))
# # print(f'{"-"*10}12{"-"*10}')
# # print(f2(1,2.3,3,4))

# %%
# f2(1,2)
# f2(1,2.2)
# f2(a=1,b=2)
# f2(a=1,b=2.2)
# f2(3,b=1)
f2('3',b=2)
# f2(1,2,'0')
# f2(a=1,b=2,c='+')
# Out:
# 1 1
# <class 'str'>
# '3-2'
