# %%
import numpy as np
x=np.random.randint(0,20,size=(100,1))
y=np.random.randint(0,10,size=(100,1))
# A=np.concatenate((x,y),axis=1)
A=np.block([x,y])
# print(A)
B=A[0]
C=B-A

D=C**2

x=np.round(np.sqrt(D[:,0]+D[:,1]),3)
print(x.reshape(100,1))
# Out:
# [[ 0.   ]
#  [ 2.236]
#  [ 2.   ]
#  [ 4.243]
#  [11.402]
#  [ 7.81 ]
#  [ 9.055]
#  [ 4.472]
#  [ 9.849]
#  [ 3.162]
#  [ 5.831]
#  [ 9.055]
#  [ 4.243]
#  [12.369]
#  [ 3.606]
#  [ 8.944]
#  [12.369]
#  [ 1.414]
#  [ 5.   ]
#  [13.601]
#  [ 5.099]
#  [ 5.385]
#  [ 6.708]
#  [ 6.708]
#  [12.369]
#  [ 2.828]
#  [ 4.472]
#  [ 3.   ]
#  [11.402]
#  [ 3.   ]
#  [ 3.606]
#  [ 7.211]
#  [ 9.434]
#  [ 5.831]
#  [ 7.071]
#  [ 9.   ]
#  [ 4.123]
#  [ 6.083]
#  [ 4.123]
#  [ 7.071]
#  [ 5.831]
#  [ 3.162]
#  [13.038]
#  [ 4.   ]
#  [ 1.   ]
#  [ 3.606]
#  [ 2.236]
#  [ 4.472]
#  [ 2.236]
#  [ 8.944]
#  [ 4.472]
#  [ 4.123]
#  [ 4.   ]
#  [13.601]
#  [ 4.472]
#  [12.649]
#  [ 5.   ]
#  [ 2.236]
#  [ 6.083]
#  [ 8.062]
#  [ 4.123]
#  [ 9.849]
#  [ 3.606]
#  [ 4.123]
#  [ 2.   ]
#  [ 6.325]
#  [ 4.472]
#  [ 8.062]
#  [12.369]
#  [ 6.083]
#  [13.   ]
#  [ 6.403]
#  [ 5.385]
#  [ 3.606]
#  [ 5.385]
#  [11.705]
#  [ 6.708]
#  [ 5.831]
#  [ 7.071]
#  [ 5.099]
#  [12.166]
#  [ 8.602]
#  [ 3.162]
#  [ 4.472]
#  [ 3.162]
#  [ 3.606]
#  [ 5.657]
#  [ 0.   ]
#  [12.649]
#  [ 3.606]
#  [ 8.062]
#  [ 3.162]
#  [ 1.   ]
#  [ 3.162]
#  [ 4.472]
#  [10.296]
#  [ 6.403]
#  [ 5.831]
#  [ 7.071]
#  [ 5.   ]]

# %%
import numpy as np
import matplotlib.pyplot as plt

#random data
x =np.random.rand(10000)
y = np.random.rand(10000)

#reshaping for blocking
x=x.reshape(10000,1) 
y=y.reshape(10000,1)
#making pair
A=np.block([x,y])
#plotting points
plt.scatter(x, y,color="blue",s=10)

#radius
r_in=0.25
r_out=0.3
#mid point
B=[0.5,0.5]

#finding distance
C=B-A
D=C**2
z=np.round(np.sqrt(D[:,0]+D[:,1]),5)
# print(z)
# print(z.reshape(1000,1))

#creating circle
for i in range(len(z)):
    if r_in<z[i]<r_out:
        plt.scatter(x[i],y[i],color='red',s=15)

# %%
x=np.random.randint(0,20,size=(100,1))
y=np.random.randint(0,10,size=(100,1))
A=np.block([x,y])

# B=(A[0]-A)**2

print(B)
# Out:
# [[  0   0]
#  [  9   9]
#  [121   4]
#  [ 16   0]
#  [144   1]
#  [  1   1]
#  [  4   1]
#  [  9   9]
#  [ 25   4]
#  [  9  25]
#  [  1   1]
#  [ 36   4]
#  [  9   1]
#  [144  25]
#  [ 25   1]
#  [  0   1]
#  [  4  16]
#  [ 49   9]
#  [ 16   1]
#  [ 49   9]
#  [  9  25]
#  [  1   0]
#  [ 49   4]
#  [ 25  25]
#  [  4   1]
#  [ 49   9]
#  [ 49   4]
#  [121  16]
#  [ 64   9]
#  [ 49  36]
#  [ 36   1]
#  [  1  25]
#  [  0   9]
#  [ 64  16]
#  [  1   4]
#  [  1   9]
#  [ 16   9]
#  [ 16   4]
#  [100   1]
#  [  1  36]
#  [  4   1]
#  [121  25]
#  [ 16  25]
#  [144   4]
#  [ 49   4]
#  [ 25   1]
#  [  4  16]
#  [  1   1]
#  [  9   0]
#  [  9  25]
#  [ 64   9]
#  [  0   1]
#  [ 16   1]
#  [ 25   4]
#  [ 49   9]
#  [  1   0]
#  [100   0]
#  [  1   9]
#  [  9   9]
#  [ 36  36]
#  [144   9]
#  [  1  16]
#  [ 81  36]
#  [  1   1]
#  [  1   9]
#  [ 25   9]
#  [ 25  25]
#  [ 64   1]
#  [ 25  16]
#  [ 64  16]
#  [ 25  36]
#  [  1   1]
#  [  4   9]
#  [ 16   1]
#  [ 16  36]
#  [  9  36]
#  [ 49  16]
#  [ 64   9]
#  [ 36  36]
#  [  4   1]
#  [ 64   0]
#  [ 81  25]
#  [ 16  36]
#  [  0   1]
#  [ 25   1]
#  [ 25   1]
#  [  9  36]
#  [ 16   1]
#  [  0  16]
#  [ 36   9]
#  [121  36]
#  [ 49  25]
#  [ 25   4]
#  [ 81   4]
#  [  1   1]
#  [  9   1]
#  [ 36   4]
#  [  4   4]
#  [ 25   9]
#  [  1   9]]

# %%
d=np.array([[3,4]])
print(np.shape(d))
# Out:
# (1, 2)

# %%
points=np.array([[4,5],[6,7],[2,3],[8,9]])
np.ndim(points)

for i in range(len(points)):
# Out:
# 4

# %%
centroids=np.array([[3,4],[7,8]])
centroids
# Out:
# array([[3, 4],
#        [7, 8]])
