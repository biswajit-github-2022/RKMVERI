# %%
import numpy as np
x=np.random.randint(0,20,size=(100,1))
y=np.random.randint(0,10,size=(100,1))
A=np.concatenate((x,y),axis=1)
B=A[0]
C=B-A

D=C**2

x=np.round(np.sqrt(D[:,0]+D[:,1]),3)
print(x.reshape(100,1))
# Out:
# [  0   5 200  49  29  34  45   4  73  40  65 153 101  68 225  50 185  90
#  145  49  64  74 104   1 100 218 100 137  53 196 205  81  40  85  97  17
#   74  45  49  25  16  50   4  10 100  53  50  72 202  34 153  68   1 149
#  149  82  90  13 170  65 100 160 145 221  17  89  82   9  73  52 109 250
#  208  65  64 106  98   5  58  97  82 178  41 149  17  10 250  37 113  73
#   20  61 170  82  82  73  52  13  25 106]
# [[ 0.   ]
#  [ 2.236]
#  [14.142]
#  [ 7.   ]
#  [ 5.385]
#  [ 5.831]
#  [ 6.708]
#  [ 2.   ]
#  [ 8.544]
#  [ 6.325]
#  [ 8.062]
#  [12.369]
#  [10.05 ]
#  [ 8.246]
#  [15.   ]
#  [ 7.071]
#  [13.601]
#  [ 9.487]
#  [12.042]
#  [ 7.   ]
#  [ 8.   ]
#  [ 8.602]
#  [10.198]
#  [ 1.   ]
#  [10.   ]
#  [14.765]
#  [10.   ]
#  [11.705]
#  [ 7.28 ]
#  [14.   ]
#  [14.318]
#  [ 9.   ]
#  [ 6.325]
#  [ 9.22 ]
#  [ 9.849]
#  [ 4.123]
#  [ 8.602]
#  [ 6.708]
#  [ 7.   ]
#  [ 5.   ]
#  [ 4.   ]
#  [ 7.071]
#  [ 2.   ]
#  [ 3.162]
#  [10.   ]
#  [ 7.28 ]
#  [ 7.071]
#  [ 8.485]
#  [14.213]
#  [ 5.831]
#  [12.369]
#  [ 8.246]
#  [ 1.   ]
#  [12.207]
#  [12.207]
#  [ 9.055]
#  [ 9.487]
#  [ 3.606]
#  [13.038]
#  [ 8.062]
#  [10.   ]
#  [12.649]
#  [12.042]
#  [14.866]
#  [ 4.123]
#  [ 9.434]
#  [ 9.055]
#  [ 3.   ]
#  [ 8.544]
#  [ 7.211]
#  [10.44 ]
#  [15.811]
#  [14.422]
#  [ 8.062]
#  [ 8.   ]
#  [10.296]
#  [ 9.899]
#  [ 2.236]
#  [ 7.616]
#  [ 9.849]
#  [ 9.055]
#  [13.342]
#  [ 6.403]
#  [12.207]
#  [ 4.123]
#  [ 3.162]
#  [15.811]
#  [ 6.083]
#  [10.63 ]
#  [ 8.544]
#  [ 4.472]
#  [ 7.81 ]
#  [13.038]
#  [ 9.055]
#  [ 9.055]
#  [ 8.544]
#  [ 7.211]
#  [ 3.606]
#  [ 5.   ]
#  [10.296]]
